# %% [markdown]
# https://youtu.be/QbPYsIleBXg

# %% [markdown]
# # Measuring Sentiment Surrounding Deafness in the Media

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [X] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# Our group explored the sentiment of language in articles from five popular news sources: ABC News, AP News, the Guardian, the New York Times, and USA Today. For our analysis, we looked at relationships between polarity and subjectivity, trends over time from the 80s to the present, and ran several statistical tests to determine if there was a significant relationship. We concluded that we can accept our hypothesis, with the caveat that our analysis only covers the articles since the 2000s because of limited data from prior to the 2000s.

# %% [markdown]
# # Names
#
# - James Larsen
# - Alejandro Servin
# - Lily Steiner
# - Mayra Trejo
# - Lucy Lennemann

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# How has the sentiment of the language surrounding Deafness used by popular online news sources (ABC, New York Times, USA Today, The Guardian, Associated Press) changed since the 80s?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# ### Background

# %% [markdown]
# From the lightbulb and internet [1] to football huddles [2] and Morse code [3], deaf people have been an influential part of American society since its origins. Public sentiment towards the Deaf community regarding their rights to access and language has been controversial and polarizing. Before we get into the importance of positive language and representation, we must first define some terminology regarding the Deaf community and American Sign Language. You may have noticed that we have been capitalizing the “D” in deaf. As with many cultures, the Deaf community takes pride in their abilities and perseverance in the face of ableism. To establish their status as a cultural group, the deaf and hard-of-hearing(hoh) use “D” deaf when discussing their community and its members. “d” deaf is used to denote the medical/scientific analysis regarding deafness, as well as, a general disconnect from the Deaf community [4]. Within the Deaf community there is the term “Deaf Gain" which “accentuates the benefits of being deaf” [5] instead of focusing on the loss of hearing. One of these gains is the ability to communicate in a loud space through the use of signed language. American Sign Language(ASL) is a form of physically expressed communication used by the Deaf community since the early 1800’s. ASL became officially recognized as a language by the academic community when William Stokoe published Dictionary of American Sign Language on Linguistic Principles in 1965 [6]. The use of ASL has long been regarded by the Deaf community as essential for growth and communication [7], though this same sentiment has not always been the viewpoint of American society. The term “audism” refers to the act of discrimination and separation on the basis of one's ability to hear[8]. Examples of audism include, but are not limited to: refusing to use written communication, prohibiting the use of ASL, refusal of service on the basis of deafness, refusal to hire an ASL interpreter, and not learning to sign for a deaf offspring.
#
# Throughout American history, the deaf and hard of hearing have been labeled many things, such as: deaf and dumb, deaf mute, and hearing impaired. All of these terms carry negative connotations in regards to a person's intellect, speaking ability, and the implication that they could “be better” if they could hear typically. To counteract these implications, the Deaf community now prefers the terms deaf and hard-of-hearing, which refer to their inability to conduct and process sound. It must also be mentioned that the term “mute” is now considered a choice in the Deaf community and not a reflection of one's ability to vocalize. Through their sense of comradery and pride, the Deaf community have been able to experience and accomplish many great strides in terms of disability rights and representation. For example, the passage of the Americans with Disabilities Act (ADA) has been said to have been largely influenced by the media exposure given to the Deaf students of Gallaudet University in 1988 during their Deaf President Now protest [9]. Due to the trail blazed by actress Marlee Matlin, Deaf performers like Nyle Dimarco, Millicent Simmonds from _A Quiet Place_(2018), and Lauren Ridolff in _The Eternals_(2021) have all been hired to portray Deaf characters in a more positive and representative light. Until recently, deaf characters were often portrayed by hearing performers as exemplified by Hawkeye in _The Avengers_(2012) and the suspense/thriller _Hush_(2016).
#
# Whether they are viewed as disabled or an inspiration, there’s no denying the impact the deaf have on American culture. Having proper representation and positive sentiment portrayed to the general public has proven to be beneficial to the accessibility and awareness of the Deaf community. In order to continue along this trajectory of inclusion we decided it would be beneficial to analyze the media rhetoric regarding the Deaf community to gain a better understanding of how representation has changed over time.

# %% [markdown]
# ### Prior Work

# %% [markdown]
# Media platforms have demonstrated both positive and unconscious bias in the Deaf community. The sentiment of language carries both negative and positive interpretations through journalistic outlets. This expression of negative opinion can be reflected through fact-based news that can create discrimination toward underrrepresented groups without that intent.
#
# Deeper into this research, there are studies that are taking the first step to reduce unconscious bias against people with disabilities by focusing on the language being used in mainstream media.
#
# In one study, researchers developed a system that can neutralize ableism in texts such as articles, books and speeches. By doing so, they developed an algorithm that identifies any subjective text and generates new sentence pairs to avoid linguistic ableism [10]. For example, if the algorithm reads “Apparently, she’s confined to a wheelchair,” the invective word would be replaced with the word “uses” to neutralize the statement. Their language database contains 1500 sentence pairs that are from movies scripts, articles, and speech transcripts that are later utilized in a BERT encoder [10]. This NLP system supports automatic identification and alternative writing against disability in text.
#
# It is important to mention, there is no standard framework to identify ableist language, but this study explores the possibility of using a pre-training concurrent model using Wiki Neutrality Corpus (WNC) from the very first generative model that can neutralize biased text. No parallel corpus of alesit language currently exists [10]. However, this study proposes a new framework to include more phrases and words that are non-inclusive of disability by collecting sub categorical text that can be used through albelm or audism language. This study also used human evaluation in their model’s generated sentences to maximize the accuracy and neutrality. Human evaluation with their BERT encoder has helped detect hidden words or phrases that are subcategories of ableism in the media.
#
# In summary, the work presented will allow us to explore the possibilities we could take to analyze the media rhetoric and so called “stigma” creating a communication barrier. The hope is that this influence can create a perspective shift so that online language and behavior that is classified as ableism and audism is not accepted within the social norm. These algorithms are being made to regulate, adjust and eliminate a negative narrative.
#
# It is important to address the attitudes in media outlets towards the Deaf community because of the insensibility and draw attention to how it is presented. This small change in mainstream media is powerful and can create conversation on a topic that should not be overlooked.

# %% [markdown]
# ### References:
# - [1] McGlinn, I. (2020, August 12). 14 Deaf and Hard-of-Hearing People Who Changed the World. Ai. Retrieved January 28, 2022, from https://www.ai-media.tv/ai-media-blog/famous-deaf-people-15-deaf-and-hard-of-hearing-people-who-changed-the-world/
# - [2] _Huddle_. Gallaudet University. (2021, February 15). Retrieved January 28, 2022, from https://www.gallaudet.edu/about/huddle/#:~:text=In%201894%2C%20the%20Gallaudet%20football,now%20known%20as%20a%20huddle
# - [3] RIT Libraries. (2021, October 26). Hist 330 Deafness and Technology: Overview. InfoGuides. Retrieved January 28, 2022, from https://infoguides.rit.edu/deaftech#:~:text=Deaf%20inventors%20developed%20the%20TTY,available%20for%20the%20Deaf%20user.
# - [4] Berke, J. (2020, January 8). Self-identification in the Deaf Community. Verywell Health. Retrieved January 28, 2022, from https://www.verywellhealth.com/deaf-culture-big-d-small-d-1046233#:~:text=Definitions,members%20of%20the%20deaf%20community.&text=In%20contrast%2C%20%22big%20D%22,quite%20proud%20to%20be%20Deaf
# - [5] Holcomb, T. K. (2013). Introduction to American Deaf Culture. Oxford University Press. Pg. 308.
# - [6] Dawn Sign Press. (2016, August 17). History of American Sign Language. https://www.dawnsign.com. Retrieved January 28, 2022, from https://www.dawnsign.com/news-detail/history-of-american-sign-language
# - [7] Scheetz, N.A. (2001). Orientation to Deafness.  Allyn & Bacon. Second ed. Pg.23.
# - [8] Merriam-Webster. (n.d.). Audism. In Merriam-Webster.com dictionary. Retrieved January 28, 2022, from https://www.merriam-webster.com/dictionary/audism
# - [9] _Deaf President Now_ - Impact. Gallaudet University. (2021, January 12). Retrieved January 28, 2022, from https://www.gallaudet.edu/about/history-and-traditions/deaf-president-now/impact/
# - [10] Liu, T.T., & Shibata, T. (2021). Automatically Neutralizing Ableist Language in Text

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We think that the language surrounding Deafness will have grown more positive since the 80s. We believe this is due to an increase in awareness of Deaf culture, there has been more positive Deaf representation in media, sports, and education.

# %% [markdown]
# # Datasets

# %% [markdown]
# We got our datasets by scraping public APIs for news sources. We queried the APIs for articles related to deafness. The APIs would return a list of URLs for articles related to our search. We then would scrape the article text and other relevant information from the URL's website.
#
# __AP News Articles, ABC News Articles, USA Today Articles__
# - datasets/ap_data.json and datasets/abc_data.json, datasets/usa_data.json
# - These datasets were made by getting article URLs from the Google Custom Search API and then scraping the articles from their news sites
#     - https://developers.google.com/custom-search/v1/introduction
# - 380 AP articles, 160 ABC articles, 1300 USA Today articles
#
# __New York Times Articles__
# - datasets/nyt_data.json
# - This dataset was made by getting article URLs from the NYT API and then scraping the articles from the NYT site
#     - https://developer.nytimes.com/
# - 750 articles
#
# __The Guardian Articles__
# - datasets/guard_data.json
# - This dataset was made by getting article URLs from The Guardian API and then scraping the articles from The Guardian website
#     - https://open-platform.theguardian.com/
# - 7000 articles
#
# These datasets should be easy to combine due to us collecting the same information for each article. The information we collected was the news source, the URL, the headline, the publishing date, and the article text.

# %% [markdown]
# # Setup

# %% [markdown]
# Here we import all of the packages necessary to visualize, clean, vectorize,  plot, and analyze the data that we scraped from the news articles.

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
import unicodedata
import nltk
from textblob import TextBlob, Word
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('omw-1.4')
from datetime import date
from collections import defaultdict
import math
import gensim
from gensim import corpora
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy import stats
# Out:
# [nltk_data] Downloading package stopwords to /home/jamie/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/jamie/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# Now that we have the packages we need, we can pull the data we need. The data we have is locally stored in the repo. The results of our API queries are stored in JSON file format.
#
# These JSON files contain a list of JSON objects, where each JSON object represents a single article. The object will contain a headline, a date as a string, the source of the article, the url of the article, as well as the article text.
#
# Here we can use pandas to read those JSON files and convert them to DataFrames.

# %%
abc_df = pd.read_json('dataset/abc_data.json')
ap_df = pd.read_json('dataset/ap_data.json') 
guard_df = pd.read_json('dataset/guard_data.json')
nyt_df = pd.read_json('dataset/nyt_data.json') 
usa_df = pd.read_json('dataset/usa_data.json')

# %% [markdown]
# Next, we set the dataframe row and column display.

# %%
pd.options.display.max_rows=6
pd.options.display.max_columns=5

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The data that we scraped is messy, and so we want to create a function to help us clean our data and get it into a standardized format. We want this function to do a number of things.
#
# #### Define a dataframe cleaning function that:
# - Renames the columns
# - Drops null values
# - Renames the source strings to their acronyms
# - Converts the date strings to pd.datetime format
# - Translate unicode artifacts from the text using unicodedata.normalize
#
# We want the columns to be renamed for easier access later in the notebook, and similarly we want the news sources to be renamed to their acronyms for similar ease of use. We want to drop null values so that we aren't working with any incomplete data. We want to convert our date strings into a format that is easier to work with. And finally we want to translate any unicode artifacts that are left over from scraping the articles off of a website into their plaintext equivalents.

# %%
def df_clean(df, source):
    df = df[['headline','date','source','url','text']]
    
    df.dropna(inplace=True)
        
    df['source'] = source

    df['date'] = pd.to_datetime(df['date'])
    df = df[~(df['date']<='1980-01-01')]
    
    df['text'] = df['text'].apply(lambda t: unicodedata.normalize('NFKD', t))
        
    return df

# %% [markdown]
# #### Apply function and visualize cleaned dataframes.

# %% [markdown]
# #### ABC News Dataframe

# %%
abc_df = df_clean(abc_df, 'abc')
abc_df.head()
# Out:
#                                             headline                date  \
# 0  Prosecutor: Alex Murdaugh now faces 71 charges... 2022-01-21 18:17:00
# 1  Undefeated: Deaf football team brings triumph ... 2021-11-20 12:59:00
# 2  Referee accused of discriminating against deaf... 2021-12-30 02:53:00
# 3  Preserving Black American Sign Language in the... 2021-02-18 19:49:00
# 4  Baby born deaf has touching reaction to hearin... 2021-03-02 01:32:00
#
#   source                                                url  \
# 0    abc  https://abcnews.go.com/US/wireStory/prosecutor...
# 1    abc  https://abcnews.go.com/US/undefeated-deaf-foot...
# 2    abc  https://abcnews.go.com/US/referee-accused-disc...
# 3    abc  https://abcnews.go.com/US/preserving-black-ame...
# 4    abc  https://abcnews.go.com/US/baby-born-deaf-touch...
#
#                                                 text
# 0  COLUMBIA, S.C. -- A once-prominent South Carol...
# 1  Once considered underdogs, the football team a...
# ...

# %% [markdown]
# #### Associated Press dataframe

# %% [markdown]
# Of the 380 AP articles we have in our dataset, 120 of them are articles that are reporting the scores of highschool basketball games. They were pulled into the dataset due to some of the schools having Deaf in their name (Tucson School-Deaf and Blind). These articles don't have any useful information, so we will drop them from our dataset.

# %%
ap_df = ap_df[ap_df['headline'].str.contains("Monday's Scores|Tuesday's Scores|Wednesday's Scores|Thursday's Scores|Friday's Scores|Saturday's Scores|Sunday's Scores")==False]

# %%
ap_df = df_clean(ap_df, 'ap')
ap_df.head()
# Out:
#                                              headline  \
# 0   2 hurt when part of student center collapses a...
# 1   Georgia hospital agrees to measures to help de...
# 3   New NYC mayor says kids safe in school despite...
# 36  Mickey Guyton, Jhené Aiko, Mary Mary to sing a...
# 37  Omicron surge is undermining care for other he...
#
#                         date source  \
# 0  2022-01-13 12:53:56+00:00     ap
# 1  2022-01-09 15:58:08+00:00     ap
# 3  2022-01-03 17:06:08+00:00     ap
# 36 2022-02-01 16:30:05+00:00     ap
# 37 2022-01-21 16:00:39+00:00     ap
#
#                                                   url  \
# 0   https://apnews.com/article/lifestyle-alabama-a...
# 1   https://apnews.com/article/georgia-us-departme...
# 3   https://apnews.com/article/coronavirus-pandemi...
# 36  https://apnews.com/article/sports-entertainmen...
# 37  https://apnews.com/article/coronavirus-pandemi...
#
#                                                  text
# ...

# %% [markdown]
# #### The Guardian Dataframe

# %%
guard_df = df_clean(guard_df, 'guard')
guard_df.head()
# Out:
#                                             headline  \
# 0  British Sign Language to become recognised lan...
# 1  Scottish health board apologises over late dia...
# 2  Strictly: sign language interpreter to be proj...
# 3  Audible review – American football film makes ...
# 4  ‘Why can’t I give it a go?’: How Rose Ayling-E...
#
#                        date source  \
# 0 2022-01-27 19:51:16+00:00  guard
# 1 2021-12-09 18:10:02+00:00  guard
# 2 2022-01-10 17:36:39+00:00  guard
# 3 2021-07-02 05:00:29+00:00  guard
# 4 2021-12-18 09:00:53+00:00  guard
#
#                                                  url  \
# 0  https://www.theguardian.com/society/2022/jan/2...
# 1  https://www.theguardian.com/society/2021/dec/0...
# 2  https://www.theguardian.com/tv-and-radio/2022/...
# 3  https://www.theguardian.com/tv-and-radio/2021/...
# 4  https://www.theguardian.com/society/2021/dec/1...
#
#                                                 text
# ...

# %% [markdown]
# #### The New York Times Dataframe

# %% [markdown]
# Old New York Times articles weren't manually transcribed, but instead were put online using software to lift the article text from pictures of old news prints. All of these older articles contain a warning at the beginning of the article informing the reader that they may have inaccuracies due to the transcription software. These warnings aren't useful to our data analysis and so can be removed from the article text.
#
# The NYT articles were also littered with odd remnants of CSS that were picked up while scraping. These remnants are always enclosed by curly brackets, so we can go through the article text and remove any bits of it enclosed in those brackets.

# %%
nyt_df['text'] = nyt_df['text'].str.replace('Credit...The New York Times Archives.*improve these archived versions.', '', regex=True)

nyt_df['text'] = nyt_df['text'].str.replace('{.*?}', '', regex=True)

# %%
nyt_df = df_clean(nyt_df, 'nyt')
nyt_df.head()
# Out:
#                                             headline  \
# 0  How the Beatles Broke Up and the Deaf Football...
# 1                         Don’t Fear a Deafer Planet
# 2  R. Allen Gardner, 91, Dies; Taught Sign Langua...
# 3  Barbara Kannapell, Activist Who Empowered Deaf...
# 4  Lesson of the Day: ‘Black, Deaf and Extremely ...
#
#                        date source  \
# 0 2021-11-19 10:30:02+00:00    nyt
# 1 2021-10-10 15:00:07+00:00    nyt
# 2 2021-10-01 16:37:51+00:00    nyt
# 3 2021-08-21 17:14:46+00:00    nyt
# 4 2021-01-29 09:00:06+00:00    nyt
#
#                                                  url  \
# 0  https://www.nytimes.com/2021/11/19/podcasts/th...
# 1  https://www.nytimes.com/2021/10/10/opinion/dea...
# 2  https://www.nytimes.com/2021/10/01/science/r-a...
# 3  https://www.nytimes.com/2021/08/21/us/barbara-...
# 4  https://www.nytimes.com/2021/01/29/learning/le...
#
#                                                 text
# ...

# %% [markdown]
# #### USA Today dataframe

# %% [markdown]
# The date pulled from the USA Today articles is in a wonky format. Instead of being in a normal date format, the date field in the database includes both a published date and a date on which the article was updated. We are interested in the date the article was published, so we want to extract that date in particular from the date field and convert it to the proper format.

# %%
usa_df['date'] = usa_df['date'].str.extract(r'Published:? (.*?)(?:Updated:?.*)?$')

# %% [markdown]
# We're adding some extra code to temporarily disable the chained assignment warning, because it dives an unneeded warning for our cleaning function. This is because of the date manipulation code we added above for this dataset.

# %%
pd.options.mode.chained_assignment = None
usa_df = df_clean(usa_df, 'usa')
pd.options.mode.chained_assignment = 'warn'

usa_df.head()
# Out:
# /home/jamie/.local/lib/python3.8/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
#                                             headline                date  \
# 0  Deaf Detroit rapper to join Eminem, Dre, Snoop... 2022-02-04 20:16:00
# 1  Black, deaf, proud: Gallaudet University embra... 2022-02-03 05:01:00
# 2  Reviewed launches new vertical dedicated to ac... 2022-01-10 08:58:00
# 3  Deer as pets: Rare piebald deer find home with... 2022-01-06 12:39:00
# 4  Man finds cockroach in ear after swimming in N... 2022-01-13 14:01:00
#
#   source                                                url  \
# 0    usa  https://www.usatoday.com/story/entertainment/m...
# 1    usa  https://www.usatoday.com/story/news/nation/202...
# ...

# %% [markdown]
# #### Combined dataframe

# %% [markdown]
# Now that we have individually cleaned all of the datasets, we can combine them into a single unified dataframe in order to easily manipulate it later.

# %%
df_list = [abc_df, ap_df, guard_df, nyt_df, usa_df]
combined_df = pd.concat(df_list).reset_index(drop=True)
combined_df.head()
# Out:
#                                             headline                 date  \
# 0  Prosecutor: Alex Murdaugh now faces 71 charges...  2022-01-21 18:17:00
# 1  Undefeated: Deaf football team brings triumph ...  2021-11-20 12:59:00
# 2  Referee accused of discriminating against deaf...  2021-12-30 02:53:00
# 3  Preserving Black American Sign Language in the...  2021-02-18 19:49:00
# 4  Baby born deaf has touching reaction to hearin...  2021-03-02 01:32:00
#
#   source                                                url  \
# 0    abc  https://abcnews.go.com/US/wireStory/prosecutor...
# 1    abc  https://abcnews.go.com/US/undefeated-deaf-foot...
# 2    abc  https://abcnews.go.com/US/referee-accused-disc...
# 3    abc  https://abcnews.go.com/US/preserving-black-ame...
# 4    abc  https://abcnews.go.com/US/baby-born-deaf-touch...
#
#                                                 text
# 0  COLUMBIA, S.C. -- A once-prominent South Carol...
# ...

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# With our datasets generated, cleaned, and combined we can begin to go through the data in order to start analyzing and exploring it. The crux of our research question is about the sentiment of the language used by these news sources. This leads us directly into our first avenue of analysis, sentiment analysis.
#
# Sentiment analysis looks at the words used in a piece of text and programmatically assesses what the mood of the writing is. This is incredibly helpful for us, because it takes a hard to analyze piece of text data and turns it into an easy to interpret numerical value.
#
# Here is the process by which we generated the sentiment analysis scores.

# %% [markdown]
# ## Generating Sentiment Analysis Scores

# %% [markdown]
# In this next section, we are creating new columns in our dataframe which will contain the analysis results. We will be using TextBlob to find the sentiment scores of the different articles. Textblob will return two variables summarizing the sentiment. First, it will return a polarity score (-1 to 1), where -1 is a negative sentiment and +1 is a positive sentiment. It also returns a subjectivity score (0 to 1) which scores how opinionated a text is, where 0 is the least subjective and 1 is the most subjective.

# %% [markdown]
# Define a function that finds sentiment within a given text:

# %%
def get_sentiment(text):
    blob = TextBlob(text)
    polarity, subjectivity = blob.sentiment
    return polarity, subjectivity

# %% [markdown]
# Now we will apply this function to each news dataframe and add two columns with the polarity score (ranging from -1 to 1) and subjectivity score (ranging from 0 to 1).

# %%
combined_df[['polarity', 'subjectivity']] = combined_df.apply(lambda x: get_sentiment(x['text']),
                                                              axis=1, result_type='expand')

# %% [markdown]
# At this point we will also make a column specifically for the year in which the article was published for easier graphing.

# %%
combined_df['year'] = combined_df['date'].apply(lambda d: d.year)
combined_df.head()
# Out:
#                                             headline                 date  \
# 0  Prosecutor: Alex Murdaugh now faces 71 charges...  2022-01-21 18:17:00
# 1  Undefeated: Deaf football team brings triumph ...  2021-11-20 12:59:00
# 2  Referee accused of discriminating against deaf...  2021-12-30 02:53:00
# 3  Preserving Black American Sign Language in the...  2021-02-18 19:49:00
# 4  Baby born deaf has touching reaction to hearin...  2021-03-02 01:32:00
#
#    ... subjectivity  year
# 0  ...     0.394252  2022
# 1  ...     0.488425  2021
# 2  ...     0.421270  2021
# 3  ...     0.389587  2021
# 4  ...     0.528889  2021
#
# [5 rows x 8 columns]

# %% [markdown]
# Now, we want to look at some visualizations of the data to get a better idea of any trends. First, let's standardize the figure size of all the graphs, set the theme and other attributes of the graph, and make a color palette to have one color represent each news source.

# %%
plt.rcParams['figure.figsize'] = (10, 7)
sns.set(context = 'talk', style='white', font_scale=1, rc={'axes.spines.right': False,'axes.spines.top': False})
newsPalette = ["#a6cee3", "#1f78b4", "#b2df8a", "#33a02c", "#fb9a99"]

# %% [markdown]
# For our first visualization, let's look at how many articles we have per year.

# %%
graph = sns.countplot(data=combined_df, x='year')
graph.xaxis.set_ticks(np.arange(0, 50, step=4))
graph.set_title("Articles Per Year")
plt.show()

# %% [markdown]
# When evaluating our results, we'll have to keep in mind that our data is much denser for 1999 onwards than for 1981-1998.

# %% [markdown]
# ## Overview of Sentiment Analysis Results

# %% [markdown]
# Now with the sentiment analysis scores generated we can begin to explore this data and get a sense of its distribution and shape.

# %% [markdown]
# ### Sentiment Data Summary

# %% [markdown]
# Here, we made a barplot showing the average polarity scores and sentiments by news source. USA is the most positive in terms of polarity. Overall, we can see a slightly positive sentiment. In terms of subjectivity, we can see that for the most part all the sources are on the more objective side since they are less than 0.5, with the Guardian being the most subjective.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Average Polarity and Subjectivity by News Source')
sns.barplot(ax=axes[1],x=combined_df['source'], y=combined_df['subjectivity'], palette=newsPalette)
sns.barplot(ax=axes[0],x=combined_df['source'], y=combined_df['polarity'], palette=newsPalette)   
plt.show()

# %% [markdown]
# Next, we made a visualization of the relationship between polarity vs subjectivity. We see a few outliers, mostly from USA Today. Generally we can see the overall trend again of our articles having a more positive sentiment and being somewhat less subjective. There doesn't seem to be much separation between different news sources however.

# %%
sns.scatterplot(data=combined_df[combined_df['year'] >= 2008], x='subjectivity', y='polarity', 
                hue='source', palette=newsPalette)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.title("Polarity vs. Subjectivity by News Source")
plt.figure(figsize=(10, 6))
plt.show()

# %% [markdown]
# ### Looking for outliers

# %% [markdown]
# With a sense of what our data generally looks like, we can now try and find any outliers in our data.
#
# With the following graphs, we looked at the distribution of the variable polarity separated by news source. The polarity represents the degree of sentiment from -1 to 1, -1 being very negative and 1 being very positive. We also included a dotted line to indicate the mean of each distribution.

# %%
plt.rcParams['figure.figsize'] = (17, 10)
newsLabels = ['abc', 'ap', 'guard', 'nyt', 'usa']
for i in range(1, 6):
    plt.subplot(2, 3, i)
    newsData = combined_df[combined_df.source == newsLabels[i - 1]]
    graph = sns.histplot(data=newsData, x='polarity', color=newsPalette[i - 1])
    graph.set_title(newsLabels[i - 1] + " news polarity")
    graph.axvline(newsData['polarity'].mean(), color='#2e2e2e', linestyle='--')
    plt.tight_layout()

# %% [markdown]
# We can see that although most news sources have a fairly normal looking distribution of polarity scores, there are a number of outliers that appear on the extremities of the x axis.
#
# Next, we take a look at the outliers in the graph for each news source and remove the articles that are irrelevant for our research question. This will also be helpful for our statistical analysis later, so that extremes don't influence our results too much. For example, looking at the graph for the Guardian, we notice some outliers that are either very positive or very negative. We filtered the dataset and looked at the text of these articles to determine whether they are relevant to our research question.

# %%
combined_df[(combined_df['source'] == 'guard') & ((combined_df['polarity'] > 0.4) | (combined_df['polarity'] < -0.2))]
# Out:
#                                                headline  \
# 2892            Wonderstruck by Brian Selznick - review
# 3300        Computer learns to understand sign language
# 4132                       Pick of the week: Rock & pop
# 4265                Books preview: David Lodge, Norwich
# 7074  A thousand years packed into a long weekend in...
#
#                            date  ... subjectivity  year
# 2892  2013-01-06 09:00:00+00:00  ...     0.625000  2013
# 3300  2009-07-10 10:00:00+00:00  ...     0.675758  2009
# 4132  2009-04-03 23:01:00+00:00  ...     0.575000  2009
# 4265  2008-10-03 23:12:06+00:00  ...     0.900000  2008
# 7074  2000-01-02 00:50:22+00:00  ...     0.540688  2000
#
# [5 rows x 8 columns]

# %% [markdown]
# For example, after looking at the article "Pick of the week: Rock & pop," we decide to remove it from our data frame as the content is irrelevant to our discussion of deaf representation in the media.

# %%
combined_df.loc[4132, 'text']
# Out:
# "David Byrne Sheffield City Hall, Sat 4 AprQuesting Talking Heads oddball and world music proselytiser revisits his collaborations with Brian Eno, including recent one Everything That Happens Will Happen Today.Bat For Lashes The Ritz, Manchester, Tue 7; Northumbria University Students' Union, Newcastle upon Tyne, Thu 9 Apr Hypnotic folk pop from the multi-instrumentalist and artist. Welcome to kooksville.Fujiya & Miyagi Cargo, London, Wed 8; The Faversham, Leeds, Thu 9; The Deaf Institute, Manchester, Fri 10 Apr Arch but infectious, built on krautrock and venturing somewhere like a space disco. Ace!"

# %% [markdown]
# The article is both seemingly nonsensical and not nearly as polar as the sentiment score would have you think. Removing articles like these is an easy and reliable approach to normalize the data.

# %%
# articles we decided to remove
combined_df = combined_df.drop(4132)
combined_df = combined_df.drop(4265)

# %% [markdown]
# In USA Today, we also noticed some irrelevant outliers that we decided to remove.

# %%
combined_df[(combined_df['source'] == 'usa') & ((combined_df['polarity'] < -0.5) | (combined_df['polarity'] > 0.6))]
# Out:
#                                                headline                 date  \
# 8337  Prep basketball: Top performers in girls high ...  2018-01-27 12:42:00
# 8438         125 pets get a new leash on life in Oregon  2018-09-08 19:53:00
# 9006                            IC preschool graduation  2014-06-01 16:29:00
#
#       ... subjectivity  year
# 8337  ...     0.377778  2018
# 8438  ...     1.000000  2018
# 9006  ...     0.775000  2014
#
# [3 rows x 8 columns]

# %%
combined_df = combined_df.drop(8337)
combined_df = combined_df.drop(8438)

# %% [markdown]
# Next, we graphed the distributions of the variable subjectivity, where 0 is least subjective and 1 is most subjective, again split up by news source and with dotted lines to indicate the mean.

# %%
newsLabels = ['abc', 'ap', 'guard', 'nyt', 'usa']
for i in range(1, 6):
    plt.subplot(2, 3, i)
    newsData = combined_df[combined_df.source == newsLabels[i - 1]]
    graph = sns.histplot(data=newsData, x='subjectivity', color=newsPalette[i - 1])
    graph.set_title(newsLabels[i - 1] + " news subjectivity")
    graph.axvline(newsData['subjectivity'].mean(), color='#2e2e2e', linestyle='--')
    plt.tight_layout()

# %% [markdown]
# Looking at the subjectivity distributions, we again check the most notable outliers and remove irrelevant articles to make the distribution curves more normal.

# %%
# AP News
combined_df[(combined_df['source'] == 'ap') & (combined_df['subjectivity'] < 0.1)]
# Out:
#                                               headline  \
# 166  Ómicron trastoca el regreso a las escuelas en ...
#
#                           date  ... subjectivity  year
# 166  2022-01-03 22:02:33+00:00  ...          0.0  2022
#
# [1 rows x 8 columns]

# %%
combined_df = combined_df.drop(166)

# %% [markdown]
# Now that we've removed some of the weird outliers that got generated we can reinspect our data.
#
# Next, we'll explore the relationship between polarity and subjectivity in different news sources by making line plots with a fitted regression line.

# %%
graph = sns.lmplot(x='polarity', y='subjectivity', col='source', hue='source', data=combined_df, height=4, 
                   col_wrap=3, palette=newsPalette)

# %% [markdown]
# It's interesting to note how articles that are more subjective tend to be more positive as well. One interpretation of this would be that if a news source has something negative to report about they try and keep it professional, while if they want to report about something positive they are more likely to use subjective language.

# %% [markdown]
# ### Interpreting sentiment over time

# %% [markdown]
# With the outliers removed from our dataset, we can begin to look at how our sentiment data changes over time, as well as interpret what is happening using real world knowledge.
#
# The following are lineplots showing the polarity and sentiment over time for each news source.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Polarity and Subjectivity by News Source Over Time')
g1 = sns.lineplot(ax=axes[0], data=combined_df, x='year', y='polarity', hue='source', ci=None, legend=False, 
                  palette=newsPalette)
g2 = sns.lineplot(ax=axes[1], data=combined_df, x='year', y='subjectivity', hue='source', ci=None, palette=newsPalette)
g1.axvline(x=1990, color='#2e2e2e', linestyle=':')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

# %% [markdown]
# Since some of our news sources don't have many articles as far back, we'll take a closer look at polarity scores with the minimum year being 2008.

# %%
lplot = sns.lineplot(data=combined_df[combined_df['year'] >= 2008], x='year', y='polarity', hue='source', ci=None, 
                     palette=newsPalette)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.title("Polarity by News Source, 2008-2022")
lplot.axvline(x=2013, color='#2e2e2e', linestyle=':')
plt.show()

# %% [markdown]
# Some of these years have scores that are relatively low in comparison, so we will investigate these. First we will look at the 1990 AP and Guardian articles from the previous figure. Next we will explore the dip in ABC, NYT, and USA in 2013.

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.options.display.max_colwidth = 130
combined_df[(combined_df['year'] == 1990) & ((combined_df['source'] == 'ap') | (combined_df['source'] == 'guard'))]
# Out:
#                                                                     headline  \
# 409           ANOTHER LOOK: White Supremacist Posse Comitatus Fades Into ...
# 410   Blind Lobby for Bill to Ban Seating Limitations on Airliners | AP News
# 7248                                                Yours sincerely, FG Pink
#
#                            date source  \
# 409   1990-09-10 04:07:00+00:00     ap
# 410   1990-02-07 07:41:00+00:00     ap
# 7248  1990-04-11 01:07:37+00:00  guard
#
#                                                                             url  \
# 409                 https://apnews.com/article/f11b9a11163961c6a81666e4dfdc1625
# 410                 https://apnews.com/article/7bd22eafb2685016dd201f62fdf22bea
# 7248  https://www.theguardian.com/society/1990/apr/11/guardiansocietysupplement
#
#                                                                                                                                    text  \
# ...

# %% [markdown]
# Looking at the following articles, it makes sense there was a low sentiment for each. One discusses an ableist bill being passed by Congress, and the others use ableist language with respect to the Deaf community. There is only one article from the Guardian and two from AP for this year, which limits the ability to make a generalized statement about the sentiment surrounding the Deaf community during this era. Considering that these are the only articles we have for this year by these two sources, and all are negatively related to the Deaf, it would be good to consider this moving forward in terms of our research question.

# %% [markdown]
# Let's explore the dip in ABC, NYT, and USA in 2013 by getting a subset of articles from that year that have a polarity score below 0.

# %%
combined_df[(combined_df['polarity'] < 0) & (combined_df['year'] == 2013) & (combined_df.source.isin(['nyt', 'usa', 'abc']))]
# Out:
#                                                               headline  \
# 127   Deaf Man Stabbed After Sign Language Mistaken for Gang Signs ...
# 129           Deaf Texas Parents Allegedly Kill Crying Baby - ABC News
# 7596                                       Art Comes to the Interstate
# 7598                                       Nebraska: Deaf Student Wins
# 7600            Deaf Patrons’ Suit Accuses Starbucks of Discrimination
# 9051               WH: No comment on Obama's sign language interpreter
# 9052              Mandela memorial interpreter used bogus signs before
# 9056                    Interpreter at Mandela memorial branded 'fake'
# 9062            Deaf man stabbed when sign language seen as gang signs
# 9064        Report: S. African interpreter charged with murder in 2003
# 9070            S. Africa investigates sign interpreter's violent past
# 9081        Mandela event signer was in group that burned men to death
# ...

# %% [markdown]
# Looking at these results, one commmon thing we can observe is that sentiment about the event where an unqualified sign interpreter was present at a memorial for Nelson Mandela has an overall low polarity score and is the subject of many of these articles (six total).
#
# Checking these dips can give us a level of confidence in the sentiment analysis scores we generated. We know that these events really did have an impact on the Deaf community, so to see that impact reflected in the sentiment scores can make us more confident that they are measuring the type of sentiment we are looking for.

# %% [markdown]
# ### Statistical analysis of sentiment over time

# %% [markdown]
# Now that we are confident in our measurement of sentiment, we can begin to do statistical analysis on it to see how it changes over time. We will focus on the last two decades, since before 2000 we have significantly less articles (see summary graph for number of articles per year)

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=combined_df[combined_df['year'] >= 2000], x='year', y='polarity', color='orange')
plt.title("Polarity Score from 2000-2022")
plt.show()

# %% [markdown]
# Generally, we can see an slight upward trend in polarity, indicating more positive language being used over the last two decades. Let's statistically analyze this trend.

# %% [markdown]
# First, we need to determine whether our data is Gaussian or not. This will determine the types of tests we can run on it. In addition to plotting our actualy data, we will plot a curve showing the expected distribution, under the hypothesis that it is normally distributed.

# %%
#make a subset for the years after 2000
subset = combined_df[combined_df['year'] >=2000].copy()
plt.figure(figsize=(10, 6))
xs = np.arange(subset['polarity'].min(), subset['polarity'].max(), 0.01)
fit = stats.norm.pdf(xs, np.mean(subset['polarity']), np.std(subset['polarity']))
plt.plot(xs, fit, label='Normal Dist.', lw=3)
plt.hist(subset['polarity'], 50, density=True, label='Actual Data', color='pink');
plt.legend();
plt.xlabel("polarity", fontsize = 20)
plt.show()

# %% [markdown]
# This graph shows the actual data in pink, and the blue line is the expected data density, with the same mean and standard deviation, if the data is normal. We can see a pretty close fit between the two. However, we will also run a normal test to more accurately asses whether our data accepts the null hypothesis and follows a normal distribution.

# %%
stat, pval = stats.normaltest(subset['polarity'])
alpha = 0.05
print('\nNormaltest p-value is: {:1.2e} \n'.format(pval))
if pval < alpha:
    print('We have evidence to reject the null hypothesis.')
else:
    print('We do not have evidence to reject the null hypothesis. This is not a normal distribution')
# Out:
# Normaltest p-value is: 6.71e-90
#
# We have evidence to reject the null hypothesis.

# %% [markdown]
# This p-value is extremely below 0.05, indicating this does NOT follow a Gaussian distribution. One thing we should keep in mind is the accuracy of this particular test on large datasets (ours is close to 9,500 articles). This test usually gives lower p-values as the data set grows bigger, which means for large datasets it tends to always report a value which rejects the null.

# %% [markdown]
# However, to be safe, we will assume our data is not Gaussian and carry on with non-parametric tests. First, we will perform a Spearman correlational test, which reports a p-value and a correlational coefficient (-1 being a strong negative correlation and 1 being a strong positive correlation).

# %%
coef, p = stats.spearmanr(subset['polarity'],subset['year'])
print('Spearmans correlation coefficient: %.3f' % coef)
print('\n p-value is: {:1.2e} \n'.format(p))
# Out:
# Spearmans correlation coefficient: 0.076
#
#  p-value is: 1.66e-12

# %% [markdown]
# We can see a slight positive correlation, with a very small p-value indicating that this slight positive correlation is not due to chance.

# %% [markdown]
# To further analyze this data, we will perform a Kruskal-Wallis test. This is a non-parametric alterantive to an ANOVA test, in which it will test the null hypothesis that the median of all groups are equal. In our case, we will be splitting our data into subsets of 3-4 years and compare the median polarity between the groups.

# %%
first = subset[(subset['year'] >=2000) & (subset['year'] < 2003) ].copy()
second = subset[(subset['year'] >=2003) & (subset['year'] < 2006) ].copy()
third  = subset[(subset['year'] >=2006) & (subset['year'] < 2009) ].copy()
fourth = subset[(subset['year'] >=2009) & (subset['year'] < 2012) ].copy()
fifth  = subset[(subset['year'] >=2012) & (subset['year'] < 2015) ].copy()
sixth = subset[(subset['year'] >=2015) & (subset['year'] < 2018) ].copy()
seventh = subset[(subset['year'] >=2018) & (subset['year'] < 2022) ].copy()
hstat, pval = stats.kruskal(first['polarity'], second['polarity'],third['polarity'],fourth['polarity'],fifth['polarity'],sixth['polarity'],seventh['polarity'])
print('Kruskal Wallis coefficient: %.3f' % hstat)
print('\n p-value is: {:1.2e} \n'.format(pval))
# Out:
# Kruskal Wallis coefficient: 53.986
#
#  p-value is: 7.43e-10

# %% [markdown]
# Our results show a very high test-statistic of 53.986. The higher the value for this test-statistic, the larger of a difference between the groups. Our p-value is very low, indicating that this is not due to random chance. Given this information, we can assume a difference of sentiment over time.

# %% [markdown]
# ### Takeaways

# %% [markdown]
# The combination of these statistical tests give us a clear picture of how word choice has generally been changing over the past two decades. We can see a underlying positive trend where the language is getting more positive with each year. We can also see that there is a lot of variance in the language between articles though, and so even though time is having an undeniably positive impact on the language being used, it isn't enough to account for all of the of variance in the data. This means that you while you can't use year to meaningfully predict an individual article's polarity score, the overall trend is still influencing the language of the articles being written as a whole.

# %% [markdown]
# ## Keyword exploration: Frequencies and TF-IDF

# %% [markdown]
# Now that we have explored sentiment analysis in relation to our dataset we can add on additional text analysis approaches to see if we can uncover any further information. By mixing approaches, we are hoping to find types of data that might not be visible using just sentiment analysis. One common approach to text analysis, other than sentiment analysis, is keyword frequency and TF-IDF analysis.
#
# In order to facilitate our exploration of keyword frequencies and TF-IDF analysis, we divided up our article texts into combined strings by news source and the year they were published in.

# %%
documents = defaultdict(lambda: defaultdict(str))

for _, _, _, source, _, text, _, _, year in combined_df.itertuples():
    documents[source][year] += text

# %% [markdown]
# We will be using the sklearn library to process these documents into their TF-IDFs, so we need the documents to be in a list format.
#
# Here we convert our dictionary into a list of strings, and preserve the keys of the dictionary in a separate list called document_names.

# %%
corpus = []
document_names = []
for source in documents.keys():
    for year in documents[source].keys():
        corpus.append(documents[source][year])
        document_names.append((source, year))

# %% [markdown]
# ### Keyword Frequencies

# %% [markdown]
# Using the corpus of article words, we can explore the frequencies of certain keywords relevant to our research, such as words for the Deaf community with positive connotations (hard of hearing, Deaf) and those with negative connotations (mute, hearing impaired).
#
# How often certain keywords or phrases occur in our articles at different points in time will give us insight into what type of language is being used, and help answer our research question of how the sentiment of the language is changing over time.

# %%
searchList = ['deaf', 'Deaf', 'mute', 'deaf and dumb', 'hearing impaired', 'hard of hearing']
freqsDict = {} 
for i in range(len(corpus)):
    source = corpus[i]
    sourceName = document_names[i]
    docFreqs = []
    for term in searchList:
        docFreqs.append(source.count(term))
    freqsDict[sourceName] = docFreqs

# %% [markdown]
# Next, we turn the freqsDict, which contains a document name such as (abc, 2022) mapped to a list of frequencies of all the search terms, into a pandas DataFrame to better understand what our data looks like.

# %%
terms = pd.DataFrame(data=freqsDict)
terms = terms.T
terms.reset_index(inplace=True)    # split the multiindex into separate columns
terms.columns = ['source', 'year', 'deaf', 'Deaf', 'mute', 'deaf and dumb', 'hearing impaired', 'hard of hearing'] 
terms['year'] = terms['year'].astype(int)
terms.head()
# Out:
#   source  year  deaf  Deaf  mute  deaf and dumb  hearing impaired  \
# 0    abc  2022     1     0     0              0                 0
# 1    abc  2021    21    21     1              4                 1
# 2    abc  2006    14     0     1              0                 0
# 3    abc  2020    45    11     0              0                 1
# 4    abc  2019    39     5     1              0                 4
#
#    hard of hearing
# 0                0
# 1                4
# 2                0
# 3                2
# 4                1

# %% [markdown]
# Then, we want to proportionalize the frequencies of each word by the number of words in each year grouped by source to account for the fact that some years have more articles than others.

# %%
news_size = [len(corpus[x]) for x in range(len(corpus))]
for i in range(2, len(terms.columns)):
    source = terms.columns[i]
    terms[source] = terms[source] / news_size[i]

terms.head()
# Out:
#   source  year      deaf      Deaf      mute  deaf and dumb  hearing impaired  \
# 0    abc  2022  0.000016  0.000000  0.000000       0.000000          0.000000
# 1    abc  2021  0.000331  0.000197  0.000007       0.000056          0.000024
# 2    abc  2006  0.000221  0.000000  0.000007       0.000000          0.000000
# 3    abc  2020  0.000709  0.000103  0.000000       0.000000          0.000024
# 4    abc  2019  0.000615  0.000047  0.000007       0.000000          0.000098
#
#    hard of hearing
# 0         0.000000
# 1         0.000114
# 2         0.000000
# 3         0.000057
# 4         0.000029

# %% [markdown]
# We also decide to drop any rows that have years prior to 1999, as many news sources don't have many articles from that time, so it will be harder to generalize any trends.

# %%
terms = terms[terms.year >= 1999]

# %% [markdown]
# Next, we visualize these frequencies using lineplots to see if there are any trends.

# %%
plt.figure(figsize=(16, 14))

for i in range(1, 7):
    plt.subplot(2, 3, i)
    if i != 1:
        sns.lineplot(data=terms, x='year', y=searchList[i - 1], hue='source', palette=newsPalette, legend=False)
    else:
        sns.lineplot(data=terms, x='year', y=searchList[i - 1], hue='source', palette=newsPalette)
    plt.tight_layout()
    plt.title(searchList[i - 1])

# %% [markdown]
# Considering these graphs, there aren't any conclusive trends, but we can observe that the keyword "deaf" is used with the highest proportions. Also, for most news sources, the keywords "deaf and dumb", "mute", and "hard of hearing" are used infrequently. One interesting thing note is the The Guardian's general downward trend for their use of the phrase "deaf and dumb" between 2000 and 2020.

# %% [markdown]
# ### TF-IDF Exploration

# %% [markdown]
# While we might not have gotten any conclusive results from keyword frequencies, we can still see what TF-IDF analysis tells us.
#
# TF-IDF of (term frequency over inverse document frequency) is a type of analysis represented by a simple mathematical equation. The equation attempts to model how significant a given word is in a piece of text. It does this by using keyword frequency as a basis, but then dividing the keyword frequency by how often the keyword appears in other documents in the corpus.
#
# This means that common words that don't mean much will have lower TF-IDF scores, while words that are used less frequently and are comparatively more meaningful will have higher TF-IDF scores. This technique has been used very successfully in order to generate keywords of news articles automatically, so we hope that by exploring TF-IDF data in relation to our own dataset we will have interesting trends emerge.

# %% [markdown]
# ### Top Keywords

# %% [markdown]
# The first step to generate TF-IDF values is to make a vectorizer and fit it to our corpus of documents.

# %%
vectorizer = TfidfVectorizer(stop_words=stopwords.words('english'))
X = vectorizer.fit_transform(corpus)
words = list(vectorizer.get_feature_names_out())

# %% [markdown]
# Now that we have our TF-IDFs in X, we want to look to see what the most significant words in each document are.
#
# Here we find the top 10 keywords for each document and add them into a new dictionary: top_tfidfs.

# %%
top_tfidfs = defaultdict(lambda: defaultdict(list))
for tfidfs, (source, year) in zip(X.toarray(), document_names):
    sorted_tfidfs = tfidfs.argsort()[:-11:-1]
    
    for index in sorted_tfidfs:
        top_tfidfs[source][year].append(words[index])

# %%
top_tfidfs['guard'][2021]
# Out:
# ['photograph',
#  'people',
#  'covid',
#  'one',
#  'said',
#  'says',
#  'film',
#  'first',
#  'us',
#  'uk']

# %%
# Getting a list of all years present in our dataset
all_years = set()
for source in top_tfidfs.keys():
    all_years = all_years.union(set(top_tfidfs[source].keys()))
all_years = list(all_years)
all_years.sort()

# %% [markdown]
# Now that we have the top keywords for each source for each year, we can print them out. We decided to only print the top 5 keywords of each source in each year to keep the representation readable.

# %%
for year in all_years:
    print(f'\n--- Year {year} ---')
    for source in top_tfidfs.keys():
        if year in top_tfidfs[source]:
            print(f'{source}: {top_tfidfs[source][year][:5]}')
# Out:
# --- Year 1981 ---
# nyt: ['deaf', 'bellitz', 'mr', 'lawhorn', 'said']
#
# --- Year 1982 ---
# nyt: ['deaf', 'handicapped', 'said', 'school', 'amy']
#
# --- Year 1983 ---
# nyt: ['deaf', 'theater', 'hearing', 'said', 'mr']
#
# --- Year 1984 ---
# nyt: ['deaf', 'schwartzberg', 'said', 'hearing', 'miss']
#
# --- Year 1985 ---
# ap: ['pickett', 'said', 'ricco', 'adamson', 'jewish']
# guard: ['fowles', 'maggot', 'travellers', 'ayscough', 'fanny']
# nyt: ['shamal', 'deaf', 'said', 'mr', 'hearing']
#
# --- Year 1986 ---
# nyt: ['deaf', 'said', 'hearing', 'mr', 'nolan']
#
# --- Year 1987 ---
# nyt: ['deaf', 'koenigsberg', 'said', 'mr', 'students']
#
# --- Year 1988 ---
# nyt: ['deaf', 'zinser', 'said', 'spilman', 'gallaudet']
#
# --- Year 1989 ---
# guard: ['tiananmen', 'deng', 'peking', 'soldiers', 'peng']
# nyt: ['deaf', 'said', 'people', 'tami', 'hanson']
#
# --- Year 1990 ---
# ap: ['posse', 'minniecheske', 'tigerton', 'faa', 'said']
# guard: ['pink', 'mr', 'fg', 'geraghty', 'mrs']
# ...

# %% [markdown]
# Looking at what keywords appeared for different sources over the years it is less informative than we might have hoped. The majority of keywords appear to be the names of people who were the topic of several articles in each year. These names are definitely significant, but they don't give us much of an idea of the language being used by these articles.
#
# It is also interesting to note covid popping up as a keyword in recent years. It makes a lot of sense as articles about the virus are probably so prevalant that they are popping up even in our subset of articles relating to deafness.

# %% [markdown]
# ### Importance of Keywords

# %% [markdown]
# We looked at the top keywords for entire years, but the issue we ran into were that the keywords were a bit too unique. Because they didn't share any similarities it was hard to make any inferences about what was happening over time. A different approach we might take would be to track how significant different keywords are for all articles.
#
# What this means is that hopefully we can choose certain keywords to inspect and see how significant they are to our body of articles over time. This is different from our keyword frequency analysis because instead of seeing strictly how often the keyword is used, we will be seeing how important the keyword is to the given articles.
#
# For this we're going to have each article be a separate document in our corpus. We will then be able to graph the TF-IDF scores for different keywords over time.

# %%
corpus = []
for text in combined_df['text']:
    corpus.append(text)

# %%
vectorizer = TfidfVectorizer(stop_words=stopwords.words('english'))
X = vectorizer.fit_transform(corpus)

# %% [markdown]
# X is a sparse matrix where every document in our corpus is a row, and every column represents a word. There is a column for every different word in the corpus (around 150,000) and the value in a given column represents the TF-IDF value of the word for the given article. This is equivalent to the significance of the keyword in the article. If the keyword isn't present in an article the TF-IDF will just be 0.
#
# We start by getting the column index of different keywords we want to track.

# %%
words = list(vectorizer.get_feature_names_out())

words_to_track = ['disabled', 'culture', 'deaf', 'cochlear', 'handicapped', 'art']
indices_to_track = [words.index(word) for word in words_to_track]

# %% [markdown]
# We can then take those columns and add them back into our dataframe.

# %%
for word, index in zip(words_to_track, indices_to_track):
    combined_df[word] = X[:, index].toarray()

# %% [markdown]
# We can now graph the distribution of significance for each keyword.

# %%
for i, word in enumerate(words_to_track):
    plt.subplot(2, 3, i+1)
    
    graph = sns.histplot(data=combined_df[combined_df[word] > 0], x=word, color=newsPalette[i%len(newsPalette)])
    graph.set_title(word)
    graph.set_xlabel('significance')
    graph.axvline(combined_df.loc[combined_df[word] > 0, word].mean(), color='#2e2e2e', linestyle='--')
    
plt.tight_layout()

# %% [markdown]
# It appears as though the significance distribution for each keyword is fairly similar. Handicapped, cochlear, and disabled stand out as having more significance generally when they appear.

# %% [markdown]
# We can also check the significance of each term over time.

# %%
for i, word in enumerate(words_to_track):
    plt.subplot(2, 3, i+1)
    
    graph = sns.lineplot(data=combined_df, x='year', y=word, color=newsPalette[i%len(newsPalette)])
    graph.set_title(f"{word} significance over time")
    graph.set_ylabel('significance')
    
plt.tight_layout()

# %% [markdown]
# Disabled as a keyword is interesting in how it grew in signifiance until around 2013 at which point it began waning in significance. A similar phenomenon has appeared to happen with art as a keyword.
#
# Culture appears to have spiked in significance in the early 1990s and then settled into a higher plateau of significance since then.
#
#
# Cochlear and handicapped both appear to be dominated by a handful of articles before 2000 and to have had little significance since.
#
# The spike of significance for cochlear and culture in the early 1990s lines up with when cochlear implants were approved by the FDA for use on children 2 years old and up in 1990. This sparked an ethical debate within Deaf culture that lasted for several years in the public eye.
#
# Finally deaf as a keyword had a major fall in significance in 2000, but since then has appeared to have had a slow growth in significance.

# %% [markdown]
# For the most part, it is hard to line this data up our understanding of these words in relation to their history, with cochlear and culture being exceptions.

# %% [markdown]
# ### TF-IDF Takeaways

# %% [markdown]
# While it was important for us to explore other approaches to text analysis, the results of our TF-IDF analysis are inconclusive in terms of our original research question. There is some valuable information to be gotten from these approaches, but perhaps not in terms of this specific research question. TF-IDF as an approach to generate keywords from a text has definitely been shown in our analysis, but applying this information to our research question is where the difficulties lie.
#
# Perhaps an area that future research can expand upon is finding a way to interpret this data, or using the TF-IDF data to answer other types of questions about our data.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Our project uses publicly available news articles from a variety of news sources.
#
# With our project, we are aware of many biases that may impact our results. First of all, because our project is surrounding Deafness, and we are all hearing, we have an innate hearing bias that will have influenced our perspective on different aspects of this project and our interpretations of the results. We also acknowledge that, due to the nature of this project, as supporters of the Deaf community we subsequently have a pro-Deafness bias that could impact a sentiment analysis because of the data we collected or how we interpret that data. Additionally, we recognize that conducting the sentiment analysis with the help of a library means it is likely that this library was made by an able-bodied individual. This could influence the results of the sentiment analysis when looking at the sentiment of the language surrounding Deafness.
#
# When collecting the news article data, we also are aware that the choices of news databases will have influenced the results of the sentiment analysis, since some news sources may be more likely to have a positive or negative sentiment on this subject. We attempted to counter this by selecting a variety of news sources to have a more comprehensive dataset. We also conducted data normalization where appropriate, since some news sources had more articles than others.
#
# Acknowledging these biases allows us to look at the results of our analysis through a more critical lens. With them in mind, we were better able to interpret this analysis since we can actively reflect on each step in case our biases are influencing our work.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# The goal of our project is to analyze whether the sentiment surrounding the Deaf community has become more positive since the 80s in popular news sources. After calculating sentiment and polarity scores for articles separated by news source (ABC, AP, Guardian, NY Times, USA Today), we noticed that most articles had a slightly positive sentiment of around 0.1 and some subjectivity of around 0.4. We also explored sentiment over time, observing dips in sentiment in the years 1990, 2013, and 2019. We can conclude that dips in sentiment of news articles are easily influenced by reportings of negative events relating to the Deaf community, such as an ableist Federal Aviation Administration rule proposed to Congress in 1990 and the use of an unqualified interpreter at a memorial in 2013. Given that language is complex, a limitation to the sentiment analysis we did is that it's not always accurate and may rate certain articles more extremely because of keywords used in the article.
#
# To get a better picture of sentiment in news sources, we also decided to examine the use of keywords such as "hearing impaired", "Deaf", "cochlear", and "disabled." The idea was that news sources that used terms that are respectful toward the Deaf community would demonstrate higher sentiment and also encourage their readers to use respectful terms. We used two techniques: keyword frequencies and TF-IDF frequencies. However, the results were inconclusive; we saw some trends, but there was a lot of variance and the data didn't end up being applicable to our research question.
#
# We also did statistical analysis, deciding to use nonparametric tests because we did not have enough evidence to conclude our distribution was normal. Using a Spearman correlation test, we can conclude that there is a statistically significant slight positive increase in polarity over time. Using a Kruskal Wallis test to compare the median of different groups, we can further our claim that there was indeed a difference in sentiment over the years.
#
# Overall, we can conlude that there has been a statistically significant increase in positive sentiment in news articles, with the caveat of our analysis only covering since the 2000s, instead of from the 1980s. This is because we have less news articles about the Deaf community from before the 2000s and therefore a limited ability to find trends. With more data, a more concrete analysis of sentiment before 2000 may be performed.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# - Alejandro Servin: Background, data cleaning, data transfer, cultural significance of the results.
# - Jamie Larsen: Worked on testing the APIs and then writing the code to scrape the corresponding websites into usable JSON files, assisted Alejandro with the data cleaning, conducted the data exploration into TF-IDF.
# - Lily Steiner: Generated sentiment scores, created visualizations of polarity and sentiment over time, performed statistical tests on data, investigated a few negative dips in time.
# - Lucy Lennemann: Helped Lily with sentiment analysis, removed outliers, visualizations for the distributions of polarity and subjectivity, conducted exploration into keyword frequencies,  conclusion.
# - Mayra Trejo: Prior work
