# %% [markdown]
# # COGS 108 - Car Accidents and Precipitation in California

# %% [markdown]
# Link to final project video: https://drive.google.com/file/d/14-Yaddk3I1jqWc7G7sdu8wAwtARfuaKM/view?usp=sharing

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [X] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# The level of precipitation has been associated with the number of car accidents that occur during the inclement weather events. For our project, we are working to determine and analyze how much precipitation can affect driving and the number of car accidents. In addition to precipitation and car accidents, we will also take into consideration the specific day of the week and the month as our confounding variables. After our complete analysis, we concluded that there is a slight relationship between precipitation and car accidents in Northern California cities, but this relationship doesn't reflect for Southern California cities.

# %% [markdown]
# # Names
#
# - Dominic Chua
# - Brandon Chen
# - Anna Morozova
# - Taha Alam
# - Yvonne Liu

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# *In the past decade, comparing the Northern and Southern California regions, is there an increased risk for car accidents in months where there is a greater amount of precipitation?*

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# **Introduction**
#
# Driving in inclement weather is generally not ideal and most people would prefer to avoid it. However, sometimes driving in inclement weather is unavoidable. Poor weather conditions, like precipitation, oftentimes present a complicated driving experience. It’s one of the main reasons why traffic can be so slow when heavy precipitation is present. They provide challenges that aren’t always present when driving under normal weather conditions, such as a sunny day. Road visibility, friction on the pavement, and overall vehicle performance can be affected by precipitation. It can also reduce drivers' perceptions of the road. It directly affects the ability of the driver to see through the rain. The ability to perceive stoplights, road markings, road signs, and even the road itself is also challenging. Wet weather creates less traction and can sometimes be difficult to keep the car in control. Precipitation is frequent in some areas, so people who have experienced it often may be more comfortable driving in it. The skill would enable them to navigate their vehicles in adverse weather conditions. Yet, even the most careful drivers can fall victim to car accidents. In our study, we are attempting to see if the relationship between car accidents and level of precipitation are more apparent in normally dry climate locations.
#
# **Background**
#
# From the U.S. Department of Transportation, weather variables such as precipitation, fog, ice, and wind speed affect the performance of roadways and drivers. Numerous weather-related accidents have been documented over the last decade.<sup>1</sup> The data collected shows that 21% of these crashes are due to weather conditions.
#
# In addition, weather-related accidents have been of growing hazard concern in the past couple of years, partly due to increased climate change. The Weather Channel claims that weather-related accidents are far more deadly than any natural disaster.<sup>2</sup> Prior research has been done for the entirety of the United States, showing that there is a 34% increase in risk of a fatal car accident during active precipitation.<sup>3</sup>
#
# According to some researched statistics, on a 10 year average, precipitation has contributed to 556,151 car accidents alone. It is surprisingly, a significant amount compared to other weather variables previously mentioned. As a result, the vast majority of weather-related accidents occur on wet pavement and during periods of heavy precipitation.<sup>4</sup> This brings to question what makes precipitation more dangerous than the other weather variables. Weather variables such as ice or snow tend to make drivers more cautious than precipitation. According to an article published by the MDPI, precipitation is a higher risk of car accident occurrences and severity compared to other inclement weather conditions. Generally, most of the serious crash impacts occur when there is a high intensity of precipitation.<sup>5</sup>
#
# According to ABC News, it states that there is an increase in the risk of car accidents to occur specifically during the winter season and at morning rush hour.<sup>6</sup> People are more likely to be involved in an accident when they are rushing around without taking caution into account. If it's raining, everyone wants to get to work quickly, but traffic is heavy, which makes it difficult for them to do so. As a result of their frustration based on their personal situations, such as being late to work, drivers may disregard traffic regulations out of impulse. People don't pay enough attention to precipitation as a factor in car accidents, despite it being one of the main risk factors.
#
# Based on a Washington Post, 73% of car accidents happen on wet pavement, which is most likely due to the aftermath of precipitation or melted snow. Another 46% of car accidents occur during precipitation. While there is only 17% of car accidents that happen during snow and 13% on icy pavement. This goes to show the vast difference between the two weather variables of precipitation and snow weather. It not only proves that people tend to be more cautious during snowy conditions, it also proves that precipitation is often overlooked. However, this data is only pertaining to the conditions that it rains more often than it does snow.<sup>7</sup>
#
# With this, it leads to our research question. If precipitation is such a high risk factor in car transportations in areas where there is consistent precipitation, we would like to see if there is a similar occurrence in areas that are more experienced with dry climate. We'd like to study the impact that recent precipitation has on car transportation and determine if this is the primary cause of these accidents specifically for California, or from some other confounding variable.
#
# References (include links):
# - 1) [How Do Weather Events Impact Roads?](https://ops.fhwa.dot.gov/weather/q1_roadimpact.htm)
# - 2) [Weather-Related Vehicle Accidents Far More Deadly Than Tornadoes, Hurricanes, Floods](https://weather.com/safety/winter/news/weather-fatalities-car-crashes-accidents-united-states)
# - 3) [Precipitation and Fatal Motor Vehicle Crashes: Continental Analysis with High-Resolution Radar Data](https://journals.ametsoc.org/view/journals/bams/100/8/bams-d-18-0001.1.xml)
# - 4) https://ops.fhwa.dot.gov/weather/q1_roadimpact.htm
# - 5) https://www.mdpi.com/2071-1050/12/19/7976/pdf
# - 6) https://abcnews.go.com/Technology/rain-increase-risk-car-crashes-light/story?id=62801469
# - 7) https://www.washingtonpost.com/news/wonk/wp/2016/01/22/why-rain-is-more-dangerous-than-snow/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that there is a positive correlation between rain in seldomly raining in areas and car related accidents in California. We chose this because California has had a dryer climate due to drought and we wanted to see if there would be an increase in car accidents due to people being unused to driving in a wet environment.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - - -
#
# 1) [Climate Data Online: Dataset Discovery](https://www.ncdc.noaa.gov/cdo-web/datasets#GHCND)
#
# - The National Oceanic and Atmospheric Administration (NOAA) is a United States organization that maintains historical and real time weather data that is publicly available. We intend to collect 10 years worth of precipitaion data from 2011 through 2021 for six different cities, three in the northern half of California and three in the southern half of California. An obversation includes the station id at which the data was recorded, the station's name, followed by the precipitation data. The combined dataset from the 6 different cities has well over 613,00 unqiue observations.
#
# - - -
#
# 2) [Statewide Integrated Traffic Records System](https://iswitrs.chp.ca.gov/Reports/jsp/CollisionReports.jsp)
#
# - The Statewide Integrated Traffic Records System (SWITRS) is a database that collects and processes data gathered from a collision scene. The Internet SWITRS application is a tool that leverages this database to allow California Highway Patrol (CHP) staff, members of its Allied Agencies, as well as researchers and members of the public to request various types of statistical reports in an electronic format. The application allows for the creation of custom reports requested by the user based on different categories including, but not limited to locations, dates, and collision types. An observation includes the case id, accident year, proc date, jurisdiction, and multiple other columns with more description on what occured during that accident, most of which is data we are not looking at. The combined dataset from the 6 different cites has well over 306,000 unqiue observations.
#
#
# - - -
#
# 3) [Precipitation Car Crash Datasets](https://github.com/DeusSeos/Precipitation-Car-Crash-Datasets)
#
# - Aggregate car crash and precipitation data for Bakersfield, Palm Springs, Sacramento, San Diego, San Jose, and Stockton. Data is from the time frame 2011 through 2021. The datasets are hosted on a public repository.
#
#
# - - -
#
# We will be using pandas to concatentate the precipitation data and car crash data into a 10-year dataframe per city. We will then perform data cleaning in order to create concise visualizations.
#
# - - -

# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(font_scale=1, style="white")

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
plt.rcParams['figure.figsize'] = (12, 5)

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", 104)

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Import all data from GitHub. DataFrames will use the following abbrieviations for cities:
# - BF: Bakersfield
# - PS: Palm Springs
# - SD: San Diego
# - SAC: Sacramento
# - SJ: San Jose
# - ST: Stockton

# %%
collision_headers = ["CASE_ID","ACCIDENT_YEAR","PROC_DATE","JURIS","COLLISION_DATE","COLLISION_TIME","OFFICER_ID",
"REPORTING_DISTRICT","DAY_OF_WEEK","CHP_SHIFT","POPULATION","CNTY_CITY_LOC","SPECIAL_COND","BEAT_TYPE","CHP_BEAT_TYPE",
"CITY_DIVISION_LAPD","CHP_BEAT_CLASS","BEAT_NUMBER","PRIMARY_RD","SECONDARY_RD","DISTANCE","DIRECTION","INTERSECTION","WEATHER_1",
"WEATHER_2","STATE_HWY_IND","CALTRANS_COUNTY","CALTRANS_DISTRICT","STATE_ROUTE","ROUTE_SUFFIX","POSTMILE_PREFIX","POSTMILE",
"LOCATION_TYPE","RAMP_INTERSECTION","SIDE_OF_HWY","TOW_AWAY","COLLISION_SEVERITY","NUMBER_KILLED","NUMBER_INJURED","PARTY_COUNT",
"PRIMARY_COLL_FACTOR","PCF_CODE_OF_VIOL","PCF_VIOL_CATEGORY","PCF_VIOLATION","PCF_VIOL_SUBSECTION","HIT_AND_RUN",
"TYPE_OF_COLLISION","MVIW","PED_ACTION","ROAD_SURFACE","ROAD_COND_1","ROAD_COND_2","LIGHTING","CONTROL_DEVICE","CHP_ROAD_TYPE",
"PEDESTRIAN_ACCIDENT","BICYCLE_ACCIDENT","MOTORCYCLE_ACCIDENT","TRUCK_ACCIDENT","NOT_PRIVATE_PROPERTY","ALCOHOL_INVOLVED",
"STWD_VEHTYPE_AT_FAULT","CHP_VEHTYPE_AT_FAULT","COUNT_SEVERE_INJ","COUNT_VISIBLE_INJ","COUNT_COMPLAINT_PAIN","COUNT_PED_KILLED",
"COUNT_PED_INJURED","COUNT_BICYCLIST_KILLED","COUNT_BICYCLIST_INJURED","COUNT_MC_KILLED","COUNT_MC_INJURED","PRIMARY_RAMP","SECONDARY_RAMP"]

# %% [markdown]
# Importing collision and weather data for Bakersfield

# %%
BF_2011_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Bakersfield/2011-2015-BF.csv")
BF_2016_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Bakersfield/2016-2021-BF.csv")
BF_weather = pd.concat([BF_2011_weather, BF_2016_weather])
BF_collision = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Bakersfield/2011-2021CollisionRecords.txt", names=collision_headers)

# %% [markdown]
# Importing collision and weather data for Palm Springs

# %%
PS_2011_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Palm-Springs/2011-2015-PS.csv")
PS_2016_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Palm-Springs/2016-2021-PS.csv")
PS_weather = pd.concat([PS_2011_weather, PS_2016_weather])
PS_collision = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Palm-Springs/2011-2021CollisionRecords.txt", names=collision_headers)

# %% [markdown]
# Importing collision and weather data for Sacramento

# %%
SAC_2011_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Sacramento/2011-2015-SAC.csv")
SAC_2016_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Sacramento/2016-2021-SAC.csv")
SAC_weather = pd.concat([SAC_2011_weather, SAC_2016_weather])
SAC_collision = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Sacramento/2011-2021CollisionRecords.txt", names=collision_headers)

# %% [markdown]
# Importing collision and weather data for San Diego

# %%
SD_2011_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/San-Diego/2011-2015-SD.csv")
SD_2016_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/San-Diego/2016-2021-SD.csv")
SD_weather = pd.concat([SD_2011_weather, SD_2016_weather])
SD_collision = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/San-Diego/2011-2021CollisionRecords.txt", names=collision_headers)

# %% [markdown]
# Importing collision and weather data for San Jose

# %%
SJ_2011_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/San-Jose/2011-2015-SJ.csv")
SJ_2016_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/San-Jose/2016-2021-SJ.csv")
SJ_weather = pd.concat([SJ_2011_weather, SJ_2016_weather])
SJ_collision = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/San-Jose/2011-2021CollisionRecords.txt", names=collision_headers)

# %% [markdown]
# Importing collision and weather data for Stockton

# %%
ST_2011_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Stockton/2011-2015-ST.csv")
ST_2016_weather = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Stockton/2016-2021-ST.csv")
ST_weather = pd.concat([ST_2011_weather, ST_2016_weather])
ST_collision = pd.read_csv("https://raw.githubusercontent.com/DeusSeos/Precipitation-Car-Crash-Datasets/main/Stockton/2011-2021CollisionRecords.txt", names=collision_headers)

# %% [markdown]
# Let's take a look at the current states of a few of our dataframes:

# %%
ST_weather.head()
# Out:
#        STATION                    NAME        DATE  DAPR  MDPR  PRCP  SNOW  \
# 0  US1CASJ0003  STOCKTON 2.1 NW, CA US  2011-01-01   NaN   NaN  0.18   NaN
# 1  US1CASJ0003  STOCKTON 2.1 NW, CA US  2011-01-02   NaN   NaN  0.20   NaN
# 2  US1CASJ0003  STOCKTON 2.1 NW, CA US  2011-01-03   NaN   NaN  0.19   NaN
# 3  US1CASJ0003  STOCKTON 2.1 NW, CA US  2011-01-04   NaN   NaN  0.00   0.0
# 4  US1CASJ0003  STOCKTON 2.1 NW, CA US  2011-01-05   NaN   NaN  0.02   NaN
#
#    SNWD
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
ST_collision.head()
# Out:
#    CASE_ID  ACCIDENT_YEAR  PROC_DATE  JURIS  COLLISION_DATE  COLLISION_TIME  \
# 0  4752440           2011   20121002   9265        20110403            1448
# 1  4752480           2011   20121010   9265        20110404            1840
# 2  4753441           2011   20120411   3905        20110216            1745
# 3  4753442           2011   20120411   3905        20110218            1604
# 4  4753445           2011   20120411   3905        20110223             854
#
#   OFFICER_ID REPORTING_DISTRICT  DAY_OF_WEEK  CHP_SHIFT  POPULATION  \
# 0      13919                NaN            7          2           6
# 1     015156                NaN            1          2           6
# 2       2072                CIV            3          5           6
# 3       2277                LAK            5          5           6
# 4       1323                LAK            3          5           6
#
#    CNTY_CITY_LOC  SPECIAL_COND  BEAT_TYPE CHP_BEAT_TYPE  CITY_DIVISION_LAPD  \
# ...

# %% [markdown]
# Here we create the functions to clean each dataframe. There are two functions used to clean the two types of dataframes:
# <br>
# <br>
# `clean_collision_data` - cleans the dataframes containing collision data
# * removes all columns except the date and the weather type of that day
# * renames the collision date column to `DATE` and weather type column to `WEATHER`
# * changes the dates in the `DATE` column to pandas `datetime` objects
# * relabels the weather type in the `WEATHER` column to actual weather patterns instead of just letters
# <br>
# <br>
#
# `clean_weather_data` - cleans the dataframes containing weather data
# * drops all columns except the `DATE` and `PRCP` columns
# * changes the dates in the `DATE` column to pandas `datetime` objects

# %%
def clean_collision_data(df):
    df = df.drop(["CASE_ID","ACCIDENT_YEAR","PROC_DATE","JURIS","COLLISION_TIME","OFFICER_ID","REPORTING_DISTRICT","DAY_OF_WEEK","CHP_SHIFT","POPULATION","CNTY_CITY_LOC","SPECIAL_COND","BEAT_TYPE","CHP_BEAT_TYPE","CITY_DIVISION_LAPD","CHP_BEAT_CLASS","BEAT_NUMBER","PRIMARY_RD","SECONDARY_RD","DISTANCE","DIRECTION","INTERSECTION","WEATHER_2","STATE_HWY_IND","CALTRANS_COUNTY","CALTRANS_DISTRICT","STATE_ROUTE","ROUTE_SUFFIX","POSTMILE_PREFIX","POSTMILE","LOCATION_TYPE","RAMP_INTERSECTION","SIDE_OF_HWY","TOW_AWAY","COLLISION_SEVERITY","NUMBER_KILLED","NUMBER_INJURED","PARTY_COUNT","PRIMARY_COLL_FACTOR","PCF_CODE_OF_VIOL","PCF_VIOL_CATEGORY","PCF_VIOLATION","PCF_VIOL_SUBSECTION","HIT_AND_RUN","TYPE_OF_COLLISION","MVIW","PED_ACTION","ROAD_SURFACE","ROAD_COND_1","ROAD_COND_2","LIGHTING","CONTROL_DEVICE","CHP_ROAD_TYPE","PEDESTRIAN_ACCIDENT","BICYCLE_ACCIDENT","MOTORCYCLE_ACCIDENT","TRUCK_ACCIDENT","NOT_PRIVATE_PROPERTY","ALCOHOL_INVOLVED","STWD_VEHTYPE_AT_FAULT","CHP_VEHTYPE_AT_FAULT","COUNT_SEVERE_INJ","COUNT_VISIBLE_INJ","COUNT_COMPLAINT_PAIN","COUNT_PED_KILLED","COUNT_PED_INJURED","COUNT_BICYCLIST_KILLED","COUNT_BICYCLIST_INJURED","COUNT_MC_KILLED","COUNT_MC_INJURED","PRIMARY_RAMP","SECONDARY_RAMP"], axis=1)
    df['COLLISION_DATE'] = pd.to_datetime(df['COLLISION_DATE'], format = '%Y%m%d')
    df = df.rename(columns  = {'COLLISION_DATE': 'DATE', 'WEATHER_1':'WEATHER'})
    df['WEATHER'] = df['WEATHER'].replace({'A': 'Clear', 'B': 'Cloudy', 'C': 'Rain', 'D': 'Snowing', 'E': 'Fog', 'F': 'Other', 'G': 'Wind'})
    df = df.sort_values('DATE').reset_index(drop=True)
    return df

def clean_weather_data(df):
    df.drop_duplicates(subset=['DATE'], inplace=True)
    df_clean = df.drop(['STATION', 'NAME', 'DAPR', 'MDPR', 'SNOW', 'SNWD'], axis=1)
    df_clean['DATE'] = pd.to_datetime(df['DATE'], format = '%Y-%m-%d')
    # df_clean = df.sort_values('DATE').reset_index(drop=True)
    return df_clean

BF_collision = clean_collision_data(BF_collision)
PS_collision = clean_collision_data(PS_collision)
SAC_collision = clean_collision_data(SAC_collision)
SD_collision = clean_collision_data(SD_collision)
SJ_collision = clean_collision_data(SJ_collision)
ST_collision = clean_collision_data(ST_collision)

BF_weather = clean_weather_data(BF_weather)
PS_weather = clean_weather_data(PS_weather)
SAC_weather = clean_weather_data(SAC_weather)
SD_weather = clean_weather_data(SD_weather)
SJ_weather = clean_weather_data(SJ_weather)
ST_weather = clean_weather_data(ST_weather)

# %% [markdown]
# Again, let's take a look at the current state of the cleaned data:

# %%
ST_weather.head()
# Out:
#         DATE  PRCP
# 0 2011-01-01  0.18
# 1 2011-01-02  0.20
# 2 2011-01-03  0.19
# 3 2011-01-04  0.00
# 4 2011-01-05  0.02

# %%
ST_collision.head()
# Out:
#         DATE WEATHER
# 0 2011-01-01  Cloudy
# 1 2011-01-01   Clear
# 2 2011-01-01    Rain
# 3 2011-01-01    Rain
# 4 2011-01-01    Rain

# %% [markdown]
# Combining our collisions on a certain day into a count.
#
# `collision_per_day` - Combines by date the given dataframe
#
# - groups dataframe by the `DATE` column
# - keep `WEATHER` column and keep the first value
# - sums up the total of the `COUNT` column

# %%
BF_collision['COUNT'] = 1
PS_collision['COUNT'] = 1
SAC_collision['COUNT'] = 1
SD_collision['COUNT'] = 1
SJ_collision['COUNT'] = 1
ST_collision['COUNT'] = 1

def collisions_per_day(df):
    return df.groupby(df['DATE']).aggregate({'WEATHER' : 'first', 'COUNT' : 'sum'}).reset_index()
    
BF_collision = collisions_per_day(BF_collision)
PS_collision = collisions_per_day(PS_collision)
SAC_collision = collisions_per_day(SAC_collision)
SD_collision = collisions_per_day(SD_collision)
SJ_collision = collisions_per_day(SJ_collision)
ST_collision = collisions_per_day(ST_collision)

# %% [markdown]
# We now want to associate the collision data with the precipitation data in one dataframe per city. We also want to add a city column for when we combine all the individual dataframes into one dataframe

# %%
BFdf = pd.merge(BF_collision, BF_weather, on='DATE', how='left')
PSdf = pd.merge(PS_collision, PS_weather, on='DATE', how='left')
SACdf = pd.merge(SAC_collision, SAC_weather, on='DATE', how='left')
SDdf = pd.merge(SD_collision, SD_weather, on='DATE', how='left')
SJdf = pd.merge(SJ_collision, SJ_weather, on='DATE', how='left')
STdf = pd.merge(ST_collision, ST_weather, on='DATE', how='left')

BFdf['CITY'] = 'BF'
PSdf['CITY'] = 'PS'
SACdf['CITY'] = 'SAC'
SDdf['CITY'] = 'SD'
SJdf['CITY'] = 'SJ'
STdf['CITY'] = 'ST'

STdf
# Out:
#            DATE WEATHER  COUNT  PRCP CITY
# 0    2011-01-01  Cloudy      8  0.18   ST
# 1    2011-01-02  Cloudy      9  0.20   ST
# 2    2011-01-03  Cloudy      6  0.19   ST
# 3    2011-01-04  Cloudy     10  0.00   ST
# 4    2011-01-05     Fog      7  0.02   ST
# ...         ...     ...    ...   ...  ...
# 3863 2021-12-25  Cloudy      1  0.03   ST
# 3864 2021-12-27  Cloudy      4  0.46   ST
# 3865 2021-12-29    Rain      4  0.35   ST
# 3866 2021-12-30   Clear      2  0.00   ST
# 3867 2021-12-31   Clear      3  0.00   ST
#
# [3868 rows x 5 columns]

# %% [markdown]
# Now that we have all the crash and weather data merged by city, we want to then combine all the dataframes into one large dataframe.

# %%
allDataFrames = [BFdf, PSdf, SACdf, SDdf, SJdf, STdf]
weatherCrashDf = pd.concat(allDataFrames)
weatherCrashDf
# Out:
#            DATE WEATHER  COUNT  PRCP CITY
# 0    2011-01-01   Clear      2  0.04   BF
# 1    2011-01-02  Cloudy      5  0.12   BF
# 2    2011-01-03   Clear      4  0.00   BF
# 3    2011-01-04   Clear      5  0.00   BF
# 4    2011-01-05   Clear      3  0.00   BF
# ...         ...     ...    ...   ...  ...
# 3863 2021-12-25  Cloudy      1  0.03   ST
# 3864 2021-12-27  Cloudy      4  0.46   ST
# 3865 2021-12-29    Rain      4  0.35   ST
# 3866 2021-12-30   Clear      2  0.00   ST
# 3867 2021-12-31   Clear      3  0.00   ST
#
# [22809 rows x 5 columns]

# %% [markdown]
# # Data Analysis & Results

# %%
# retrieve the data 

weatherCrashDf = pd.read_csv('weatherCrashDf.csv')
weatherCrashDf.rename(columns = {'COUNT':'COLLISIONS'}, inplace = True)
weatherCrashDf
# Out:
#              DATE WEATHER  COLLISIONS  PRCP CITY
# 0      2011-01-01   Clear           2  0.04   BF
# 1      2011-01-02  Cloudy           5  0.12   BF
# 2      2011-01-03   Clear           4  0.00   BF
# 3      2011-01-04   Clear           5  0.00   BF
# 4      2011-01-05   Clear           3  0.00   BF
# ...           ...     ...         ...   ...  ...
# 22804  2021-12-25  Cloudy           1  0.03   ST
# 22805  2021-12-27  Cloudy           4  0.46   ST
# 22806  2021-12-29    Rain           4  0.35   ST
# 22807  2021-12-30   Clear           2  0.00   ST
# 22808  2021-12-31   Clear           3  0.00   ST
#
# [22809 rows x 5 columns]

# %% [markdown]
# Carry out EDA on your dataset(s); Describe in this section

# %%
# get statistical recap of the dataset
weatherCrashDf.describe()
# Out:
#          COLLISIONS          PRCP
# count  22809.000000  18712.000000
# mean      13.479372      0.035006
# std        9.188621      0.184984
# min        1.000000      0.000000
# 25%        6.000000      0.000000
# 50%       12.000000      0.000000
# 75%       19.000000      0.000000
# max       72.000000      7.000000

# %% [markdown]
# First we will look at the descriptive statistics of our data. Here we see that we have high standard deviation for COLLISIONS so the data has a high variance. Whereas for PRCP, the data variance is smaller in comparison. In the count column we have 22,809 values for COLLISIONS and 18,712 values for PRCP which is sufficient to make a reliable analysis.

# %%
# determine what weather types we have
weatherCrashDf['WEATHER'].unique()
# Out:
# array(['Clear', 'Cloudy', 'Fog', 'Rain', '-', 'Snowing', 'Wind', 'Other'],
#       dtype=object)

# %%
# see the relation between variables
fig = pd.plotting.scatter_matrix(weatherCrashDf[['DATE', 'WEATHER', 'COLLISIONS','PRCP','CITY']])
fig
# Out:
# array([[<AxesSubplot:xlabel='COLLISIONS', ylabel='COLLISIONS'>,
#         <AxesSubplot:xlabel='PRCP', ylabel='COLLISIONS'>],
#        [<AxesSubplot:xlabel='COLLISIONS', ylabel='PRCP'>,
#         <AxesSubplot:xlabel='PRCP', ylabel='PRCP'>]], dtype=object)

# %%
# collisions & precipitation
sns.scatterplot(x = 'PRCP', y = 'COLLISIONS', data = weatherCrashDf)
# Out:
# <AxesSubplot:xlabel='PRCP', ylabel='COLLISIONS'>

# %% [markdown]
# Based on this scatter plot, you can see that most of the collisions are clustered near only mere inches of precipitation. It only shows to prove that there doesn’t need to be high intensity of rainfall for collisions to occur. However, there is little to no linear correlation between PRCP and COLLISIONS when we analyze the data for all cities.
#
# Let's take a look at distributions for PRCP and COLLISIONS

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,sharey = True)
sns.histplot(weatherCrashDf['PRCP'],bins=15,ax=ax1,color='blue')
ax1.set_title('Precipitation')
ax1.set_xlabel('')

sns.histplot(weatherCrashDf['COLLISIONS'],bins=15, color = 'red')
ax2.set_title('COLLISIONS')
ax2.set_xlabel('')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# As we can see in both distributions of precipitation and collision, they are severely skewed to the right. With the histogram we can estimate the range of our data that will be utilized in further analysis.
#
# PRCP(0,1), COLLISIONS (0.45) and all other values deviate too much from the distribution itself. Next, we will take a look at how many outliers we have in PRCP and COLLISIONS

# %%
print('COLLISIONS outliers:')
print(len(weatherCrashDf[weatherCrashDf['COLLISIONS']>45]))
print('PRCP outliers:')
print(len(weatherCrashDf[weatherCrashDf['PRCP']>1]))
# Out:
# COLLISIONS outliers:
# 39
# PRCP outliers:
# 124

# %%
# collisons & precipitation by city
sns.lineplot(x = 'COLLISIONS', y = 'PRCP', hue = 'CITY',data = weatherCrashDf)
# Out:
# <AxesSubplot:xlabel='COLLISIONS', ylabel='PRCP'>

# %% [markdown]
# From the above plot, it's not clear if PRCP can affect COLLISIONS. Next we will look at the level of collisions based on PRCP in each city and compare them to each other.
#
# From the plot, it’s not clear if PRCP can affect COLLISIONS. You can see that SJ (San Jose) itself has higher precipitation than the rest of the cities and correlates to about an average of 20 COLLISIONS. If we look at SD (San Diego) , there’s not a lot of precipitation that occurs when that correlates to the COLLISIONS. It does show a bit of activity where the higher number of COLLISIONS occur in roughly about 1 inch of precipitation. However, it’s a bit difficult to see a difference between the cities with all of them coinciding with each other.

# %%
bf = weatherCrashDf[(weatherCrashDf['CITY']=='BF')]
ps = weatherCrashDf[(weatherCrashDf['CITY']=='PS')]
sac = weatherCrashDf[(weatherCrashDf['CITY']=='SAC')]
sd = weatherCrashDf[(weatherCrashDf['CITY']=='SD')]
sj = weatherCrashDf[(weatherCrashDf['CITY']=='SJ')]
st = weatherCrashDf[(weatherCrashDf['CITY']=='ST')]

fig, (ax1,ax2,ax3) = plt.subplots(ncols = 3,sharey = True)
fig.suptitle('South California')
sns.lineplot(x = 'COLLISIONS', y = 'PRCP',data = bf,ax=ax1, color = 'orange')
ax1.set_title('Bakersfield')
ax1.set_xlabel('Collisions')

sns.lineplot(x = 'COLLISIONS', y = 'PRCP',data = ps,ax=ax2, color = 'orange')
ax2.set_title('Palm Springs')
ax2.set_xlabel('Collisions')

sns.lineplot(x = 'COLLISIONS', y = 'PRCP',data = sd,ax=ax3, color = 'orange')
ax3.set_title('San Diego')
ax3.set_xlabel('Collisions')
# Out:
# Text(0.5, 0, 'Collisions')

# %% [markdown]
# Utilizing line plots we’re going to see the relationship for each city in comparison.
#
# We can see that in Bakersfield and San Diego there are more COLLISIONS when PRCP is higher. However, when we take a lot at Palm Springs the COLLISIONS aren’t affected that much by the PRCP.

# %%
fig, (ax1,ax2,ax3) = plt.subplots(ncols = 3,sharey = True)
fig.suptitle('North California')
sns.lineplot(x = 'COLLISIONS', y = 'PRCP',data = sac,ax=ax1, color = 'blue')
ax1.set_title('Sacramento')
ax1.set_xlabel('collisions')
sns.lineplot(x = 'COLLISIONS', y = 'PRCP',data = sj,ax=ax2, color = 'blue')
ax2.set_title('San Jose')
ax2.set_xlabel('collisions')
sns.lineplot(x = 'COLLISIONS', y = 'PRCP',data = st,ax=ax3, color = 'blue')
ax3.set_title('Stockton')
ax3.set_xlabel('collisions')
# Out:
# Text(0.5, 0, 'collisions')

# %% [markdown]
# Here we can see a similar trend of Bakersfield and San Diego for Sacramento and San Jose, where there are more COLLISIONS that occur when PRCP is higher. While Stockton is the least affected by the precipitation variable.
#
# Next we will have a closer look at the number of COLLISIONS that happen on a specific day of the week.

# %%
# analyze data by day of the week
#creating a dataframe copy with weekdays
wc = weatherCrashDf.copy(deep=True)
wc['DATE'] = pd.to_datetime(wc['DATE']).dt.strftime("%a")
wc

# collisions by day of the week
plt = sns.lineplot(x = 'DATE', y = 'COLLISIONS',data = wc, color = 'red').set(title='COLLISIONS DURING A WEEK')
plt
# Out:
# [Text(0.5, 1.0, 'COLLISIONS DURING A WEEK')]

# %% [markdown]
# We can see that the number of COLLISIONS start to increase gradually from Sunday and all the way to Friday where it peaks. This graph could support the idea that many people are rushing to go home after a day’s work and at a time where many people are eager to have their weekend fun.

# %%
# collisions by day of the week by city
plt1 = sns.lineplot(x = 'DATE', y = 'COLLISIONS', hue = 'CITY',data = wc).set(title='COLLISIONS DURING A WEEK')
plt1
# Out:
# [Text(0.5, 1.0, 'COLLISIONS DURING A WEEK')]

# %% [markdown]
# We will continue to explore the data by creating some line plots to display the average COLLISIONS in each city. Here we break it down and can see that only the cities Sacramento, San Jose, and San Diego follow a gradually increasing trend starting from Sunday which peaks on Friday. We can see that the trend is somewhat visible for Bakersfield and Stockton. However, it is completely absent from Palm Springs.
#
# Next let’s take a look if there’s a similar trend based on the specific month of the year.

# %%
# analyze data by month of the year
#creating a dataframe copy with months not to mess with the previous data
wc_m = weatherCrashDf.copy(deep=True)
wc_m['DATE'] = pd.to_datetime(wc_m['DATE']).dt.strftime("%B %Y")
wc_m

# collisions by day of the week
sns.lineplot(x = 'DATE', y = 'COLLISIONS',data = wc_m, color = 'red').set(title='COLLISIONS BY MONTH')
# Out:
# [Text(0.5, 1.0, 'COLLISIONS BY MONTH')]

# %%
sns.lineplot(x = 'DATE', y = 'COLLISIONS',hue = 'CITY', data = wc_m, color = 'red').set(title='COLLISIONS BY MONTH')
# Out:
# [Text(0.5, 1.0, 'COLLISIONS BY MONTH')]

# %% [markdown]
# On average, we can see that starting from July there’s a gradual increase until it peaks in October.
#
# As we break it down by each city, we can see that COLLISIONS do tend to increase at a certain month, but it varies for each city. For example, in San Diego, there’s a gradual increase after the month of May. While in San Jose, there’s a gradual increase after the month of July. The only consistent trend is that they all seem to peak at the month of October.

# %% [markdown]
# ##### We now change our dataframes to now sum the collisions and also take the mean precipitation per month for all the years to account for month and day as confounding variables

# %% [markdown]
# Change Bakersfield to have a sum of collisions and mean of precipitation seperated by month and year

# %%
BFdf_month = BFdf.copy(deep=True)
BFdf_month['DATE'] = pd.to_datetime(BFdf_month['DATE']).dt.strftime("%B %Y")
BFdf_month = BFdf_month.groupby(['DATE'], sort=False).agg(COUNT=('COUNT', 'sum'), PRCP = ('PRCP', 'mean')).reset_index()
BFdf_month
# Out:
#                DATE  COUNT      PRCP
# 0      January 2011    154  0.012903
# 1     February 2011    166  0.017500
# 2        March 2011    150  0.053871
# 3        April 2011    152  0.006207
# 4          May 2011    182  0.007419
# ..              ...    ...       ...
# 127     August 2021    151  0.000000
# 128  September 2021    256  0.000000
# 129    October 2021    281  0.030323
# 130   November 2021    256  0.000333
# 131   December 2021    281  0.083871
#
# [132 rows x 3 columns]

# %% [markdown]
# Change Palm Springs to have a sum of collisions and mean of precipitation seperated by month and year

# %%
PSdf_month = PSdf.copy(deep=True)
PSdf_month['DATE'] = pd.to_datetime(PSdf_month['DATE']).dt.strftime("%B %Y")
PSdf_month = PSdf_month.groupby(['DATE'], sort=False).agg(COUNT=('COUNT', 'sum'), PRCP = ('PRCP', 'mean')).reset_index()
PSdf_month
# Out:
#                DATE  COUNT      PRCP
# 0      January 2011     45  0.000000
# 1     February 2011     35  0.047895
# 2        March 2011     48  0.012000
# 3        April 2011     46  0.000000
# 4          May 2011     45  0.000000
# ..              ...    ...       ...
# 127     August 2021     32  0.000000
# 128  September 2021     35  0.028889
# 129    October 2021     36  0.025000
# 130   November 2021     42  0.000000
# 131   December 2021     37  0.047619
#
# [132 rows x 3 columns]

# %% [markdown]
# Change San Diego to have a sum of collisions and mean of precipitation seperated by month and year

# %%
SDdf_month = SDdf.copy(deep=True)
SDdf_month['DATE'] = pd.to_datetime(SDdf_month['DATE']).dt.strftime("%B %Y")
SDdf_month = SDdf_month.groupby(['DATE'], sort=False).agg(COUNT=('COUNT', 'sum'), PRCP = ('PRCP', 'mean')).reset_index()
SDdf_month
# Out:
#                DATE  COUNT      PRCP
# 0      January 2011    649       NaN
# 1     February 2011    626  0.217692
# 2        March 2011    663  0.075806
# 3        April 2011    591  0.013448
# 4          May 2011    663  0.039032
# ..              ...    ...       ...
# 127     August 2021    752  0.001000
# 128  September 2021    786  0.001111
# 129    October 2021    811  0.047742
# 130   November 2021    702  0.000333
# 131   December 2021    661  0.130323
#
# [132 rows x 3 columns]

# %% [markdown]
# Change Sacramento to have a sum of collisions and mean of precipitation seperated by month and year

# %%
SACdf_month = SACdf.copy(deep=True)
SACdf_month['DATE'] = pd.to_datetime(SACdf_month['DATE']).dt.strftime("%B %Y")
SACdf_month = SACdf_month.groupby(['DATE'], sort=False).agg(COUNT=('COUNT', 'sum'), PRCP = ('PRCP', 'mean')).reset_index()
SACdf_month
# Out:
#                DATE  COUNT      PRCP
# 0      January 2011    477  0.053871
# 1     February 2011    457  0.121071
# 2        March 2011    558  0.224194
# 3        April 2011    386  0.002000
# 4          May 2011    475  0.032903
# ..              ...    ...       ...
# 127     August 2021    574  0.000000
# 128  September 2021    610  0.005667
# 129    October 2021    612  0.237097
# 130   November 2021    512  0.026333
# 131   December 2021    536  0.243226
#
# [132 rows x 3 columns]

# %% [markdown]
# Change San Jose to have a sum of collisions and mean of precipitation seperated by month and year

# %%
SJdf_month = SJdf.copy(deep=True)
SJdf_month['DATE'] = pd.to_datetime(SJdf_month['DATE']).dt.strftime("%B %Y")
SJdf_month = SJdf_month.groupby(['DATE'], sort=False).agg(COUNT=('COUNT', 'sum'), PRCP = ('PRCP', 'mean')).reset_index()
SJdf_month
# Out:
#                DATE  COUNT      PRCP
# 0      January 2011    589       NaN
# 1     February 2011    540       NaN
# 2        March 2011    552       NaN
# 3        April 2011    514       NaN
# 4          May 2011    564       NaN
# ..              ...    ...       ...
# 127     August 2021    456       NaN
# 128  September 2021    455       NaN
# 129    October 2021    521  1.070000
# 130   November 2021    424       NaN
# 131   December 2021    449  0.236667
#
# [132 rows x 3 columns]

# %% [markdown]
# Change Stockton to have a sum of collisions and mean of precipitation seperated by month and year

# %%
STdf_month = STdf.copy(deep=True)
STdf_month['DATE'] = pd.to_datetime(STdf_month['DATE']).dt.strftime("%B %Y")
STdf_month = STdf_month.groupby(['DATE'], sort=False).agg(COUNT=('COUNT', 'sum'), PRCP = ('PRCP', 'mean')).reset_index()
STdf_month
# Out:
#                DATE  COUNT      PRCP
# 0      January 2011    268  0.034839
# 1     February 2011    301  0.093929
# 2        March 2011    309  0.128387
# 3        April 2011    272  0.001724
# 4          May 2011    273  0.033871
# ..              ...    ...       ...
# 127     August 2021    409  0.000000
# 128  September 2021    385  0.002667
# 129    October 2021    283  0.187419
# 130   November 2021    346  0.024000
# 131   December 2021    284  0.179655
#
# [132 rows x 3 columns]

# %% [markdown]
# To compare the Northern and Southern California regions, let's concatenate the corresponding dataframes together.

# %%
NCdf_month = pd.concat([SACdf_month, STdf_month, SJdf_month])
SCdf_month = pd.concat([PSdf_month, SDdf_month, BFdf_month])

# %% [markdown]
# Now let's plot the amount of accidents per month against average monthly precipitation to see if we can visually determine a correlation between the two variables.

# %%
# create dot plot for Northern California
g = sns.lmplot(x = 'COUNT', y = 'PRCP', data = SCdf_month)
g = (g.set_axis_labels('Total Car Accident Count', 'Average Daily Precipitation'))

# %% [markdown]
# As you can see there is no direct correlation on the averages. However, if we check it through the OLS regression results, we see there is a slight positive correlation.

# %%
# run linear regression for Northern California dataset
NCdf = NCdf_month[['COUNT','PRCP']]

outcome, predictors = patsy.dmatrices('COUNT ~ PRCP', NCdf)
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COUNT   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     6.560
# Date:                Sat, 12 Mar 2022   Prob (F-statistic):             0.0110
# Time:                        16:57:48   Log-Likelihood:                -1697.7
# No. Observations:                 266   AIC:                             3399.
# Df Residuals:                     264   BIC:                             3407.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    365.4553     10.067     36.303      0.000     345.634     385.277
# ...

# %% [markdown]
# Let's do the same for the Southern California cities:

# %%
# create dot plot for Southern California
g = sns.lmplot(x = 'COUNT', y = 'PRCP', data = SCdf_month)
g = (g.set_axis_labels('Total Car Accident Count', 'Average Daily Precipitation'))

# %% [markdown]
# Again, here we see there's no correlation within Southern California.

# %%
# run linear regression for Southern California dataset
SCdf = SCdf_month[['COUNT','PRCP']]

outcome, predictors = patsy.dmatrices('COUNT ~ PRCP', SCdf)
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COUNT   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.6924
# Date:                Sat, 12 Mar 2022   Prob (F-statistic):              0.406
# Time:                        15:54:20   Log-Likelihood:                -2830.1
# No. Observations:                 395   AIC:                             5664.
# Df Residuals:                     393   BIC:                             5672.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    340.0135     17.474     19.458      0.000     305.659     374.368
# ...

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# All of the data present in our project are collected from sources that are open to the public for usage. Therefore, there are little ethical and privacy concerns associated with our collected datasets.
#
# Going into this project, in the event that there will be personal information found in the data that we have collected, we are fully prepared to handle it appropriately with the privacy of others in mind. Any found personal information will be nulled and covered, such as car types, economical statuses, names, and race. All personal information will not be shown to the public view.
#
# We also foresee any stereotypical driving troupes that may be discriminatory against race and gender. Since our data will be centered around Northern and Southern Californians, we do not believe there will be any bias that may invalidate the data sets that we are working with. Much of the data sets that we are working with aren't directed towards a certain social group of any kind and we are solely utilizing the quantitative data to aid our data science research. Our findings and conclusions will be used to justify the concerns of driving during weather-based conditions, specifically under precipitation in areas where the population is not used to such weather conditions.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# Through our initial research, it has indicated that the level of precipitation has a huge contributing influence on car collisions. We can see that this is evident in our analysis in the Northern California region. This was highlighted in our linear regression plots and the OSL line regression model. In the regression model, we have a p-value of 0.011 against our pre-determined alpha level of 0.05. Since our p-value is well below our alpha, we have strong evidence to suggest that there is a positive correlation between the number of car accidents and average precipitation in a given month.
#
# On the other hand, this is quite the opposite in the Southern California region. We have a p-value of 0.406 against our alpha level of 0.05. This p-value is well above our alpha, so we do not have substantial evidence to suggest that there is a correlation between the number of car accidents and average precipitation in a given month in Southern California.
#
# With all this being said, we are concluding that precipitation is not the primary causality in increased car accident risk. As we make this assumption, we would move forward analyzing that there are other possible variables such as general climate, the amount of traffic or different tire-make in a given region, that would be confounding variables to our analysis.

# %% [markdown]
# # Contributions

# %% [markdown]
# - Import & Wrangle Data (Dominic Chua)
# - EDA (Exploratory Data Analysis) (Anna Morozova)
# - Finalize Wrangling/EDA (Brandon Chen)
# - Begin Analysis (Taha Alam)
# - Complete Analysis (Yvonne Liu)
